# %%
import pandas as pd

# %%
data = pd.read_csv('Realestate.csv')

# %%
data.head()
# Out:
#    No  transaction  houseAge  distanceToNearestMRTstation  \
# 0   1     2012.917      32.0                     84.87882
# 1   2     2012.917      19.5                    306.59470
# 2   3     2013.583      13.3                    561.98450
# 3   4     2013.500      13.3                    561.98450
# 4   5     2012.833       5.0                    390.56840
#
#    numberOfConvenienceStores  latitude  longitude  housePriceOfUnitArea
# 0                         10  24.98298  121.54024                   NaN
# 1                          9  24.98034  121.53951                  42.2
# 2                          5  24.98746  121.54391                  47.3
# 3                          5  24.98746  121.54391                  54.8
# 4                          5  24.97937  121.54245                  43.1

# %%
data.dtypes
# Out:
# No                               int64
# transaction                    float64
# houseAge                       float64
# distanceToNearestMRTstation    float64
# numberOfConvenienceStores        int64
# latitude                       float64
# longitude                      float64
# housePriceOfUnitArea           float64
# dtype: object

# %%
data.houseAge.mean
# Out:
# <bound method Series.mean of 0      32.0
# 1      19.5
# 2      13.3
# 3      13.3
# 4       5.0
#        ...
# 413    13.7
# 414     5.6
# 415    18.8
# 416     8.1
# 417     6.5
# Name: houseAge, Length: 418, dtype: float64>

# %%
data.houseAge
# Out:
# 0      32.0
# 1      19.5
# 2      13.3
# 3      13.3
# 4       5.0
#        ...
# 413    13.7
# 414     5.6
# 415    18.8
# 416     8.1
# 417     6.5
# Name: houseAge, Length: 418, dtype: float64

# %%
#Normalize the data in the houseAge column.
data.houseAge.min()
# Out:
# 0.0

# %%
data.houseAge.max()
# Out:
# 43.8

# %%
data.houseAge.mean()
# Out:
# 17.620334928229664

# %%
data.houseAge.std()
# Out:
# 11.428348063298536

# %%
houseAge = data.houseAge

# %%
norm = (houseAge - houseAge.mean())/ houseAge.std()
norm
# Out:
# 0      1.258245
# 1      0.164474
# 2     -0.378037
# 3     -0.378037
# 4     -1.104301
#          ...
# 413   -0.343036
# 414   -1.051800
# 415    0.103223
# 416   -0.833046
# 417   -0.973048
# Name: houseAge, Length: 418, dtype: float64

# %%
minmax = (houseAge - houseAge.min())/ (houseAge.max() - houseAge.min())
minmax
# Out:
# 0      0.730594
# 1      0.445205
# 2      0.303653
# 3      0.303653
# 4      0.114155
#          ...
# 413    0.312785
# 414    0.127854
# 415    0.429224
# 416    0.184932
# 417    0.148402
# Name: houseAge, Length: 418, dtype: float64

# %%
minmax.min()
# Out:
# 0.0

# %%
minmax.max()
# Out:
# 1.0

# %%
data
# Out:
#       No  transaction  houseAge  distanceToNearestMRTstation  \
# 0      1     2012.917      32.0                     84.87882
# 1      2     2012.917      19.5                    306.59470
# 2      3     2013.583      13.3                    561.98450
# 3      4     2013.500      13.3                    561.98450
# 4      5     2012.833       5.0                    390.56840
# ..   ...          ...       ...                          ...
# 413  410     2013.000      13.7                   4082.01500
# 414  411     2012.667       5.6                     90.45606
# 415  412     2013.250      18.8                    390.96960
# 416  413     2013.000       8.1                    104.81010
# 417  414     2013.500       6.5                     90.45606
#
#      numberOfConvenienceStores  latitude  longitude  housePriceOfUnitArea
# 0                           10  24.98298  121.54024                   NaN
# 1                            9  24.98034  121.53951                  42.2
# ...

# %%
data['standardized_houseAge'] = norm

# %%
#Created a new column labeled houseAgeStandardized to hold the data normalized in the houseAge column.
data.new_column = norm
# Out:
# C:\Users\lesha\AppData\Local\Temp\ipykernel_20868\2295043221.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   data.new_column = norm

# %%
data.head()
# Out:
#    No  transaction  houseAge  distanceToNearestMRTstation  \
# 0   1     2012.917      32.0                     84.87882
# 1   2     2012.917      19.5                    306.59470
# 2   3     2013.583      13.3                    561.98450
# 3   4     2013.500      13.3                    561.98450
# 4   5     2012.833       5.0                    390.56840
#
#    numberOfConvenienceStores  latitude  longitude  housePriceOfUnitArea  \
# 0                         10  24.98298  121.54024                   NaN
# 1                          9  24.98034  121.53951                  42.2
# 2                          5  24.98746  121.54391                  47.3
# 3                          5  24.98746  121.54391                  54.8
# 4                          5  24.97937  121.54245                  43.1
#
#    standardized_houseAge
# 0               1.258245
# 1               0.164474
# 2              -0.378037
# 3              -0.378037
# 4              -1.104301

# %%
data.drop(columns=['numberOfConvenienceStores'])
# Out:
#       No  transaction  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1     2012.917      32.0                     84.87882  24.98298
# 1      2     2012.917      19.5                    306.59470  24.98034
# 2      3     2013.583      13.3                    561.98450  24.98746
# 3      4     2013.500      13.3                    561.98450  24.98746
# 4      5     2012.833       5.0                    390.56840  24.97937
# ..   ...          ...       ...                          ...       ...
# 413  410     2013.000      13.7                   4082.01500  24.94155
# 414  411     2012.667       5.6                     90.45606  24.97433
# 415  412     2013.250      18.8                    390.96960  24.97923
# 416  413     2013.000       8.1                    104.81010  24.96674
# 417  414     2013.500       6.5                     90.45606  24.97433
#
#      longitude  housePriceOfUnitArea  standardized_houseAge
# ...

# %%
#Dropped numberOfConvenientStores column and applied this change to the data set.
data.drop(columns=['numberOfConvenienceStores'], inplace=True)

# %%
data
# Out:
#       No  transaction  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1     2012.917      32.0                     84.87882  24.98298
# 1      2     2012.917      19.5                    306.59470  24.98034
# 2      3     2013.583      13.3                    561.98450  24.98746
# 3      4     2013.500      13.3                    561.98450  24.98746
# 4      5     2012.833       5.0                    390.56840  24.97937
# ..   ...          ...       ...                          ...       ...
# 413  410     2013.000      13.7                   4082.01500  24.94155
# 414  411     2012.667       5.6                     90.45606  24.97433
# 415  412     2013.250      18.8                    390.96960  24.97923
# 416  413     2013.000       8.1                    104.81010  24.96674
# 417  414     2013.500       6.5                     90.45606  24.97433
#
#      longitude  housePriceOfUnitArea  standardized_houseAge
# ...

# %%
data.rename(columns={"transaction" : "transactionDate"})
# Out:
#       No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1         2012.917      32.0                     84.87882  24.98298
# 1      2         2012.917      19.5                    306.59470  24.98034
# 2      3         2013.583      13.3                    561.98450  24.98746
# 3      4         2013.500      13.3                    561.98450  24.98746
# 4      5         2012.833       5.0                    390.56840  24.97937
# ..   ...              ...       ...                          ...       ...
# 413  410         2013.000      13.7                   4082.01500  24.94155
# 414  411         2012.667       5.6                     90.45606  24.97433
# 415  412         2013.250      18.8                    390.96960  24.97923
# 416  413         2013.000       8.1                    104.81010  24.96674
# 417  414         2013.500       6.5                     90.45606  24.97433
#
#      longitude  housePriceOfUnitArea  standardized_houseAge
# ...

# %%
#Changed the transaction column name to transactionDate
data.rename(columns={"transaction": "transactionDate"}, inplace=True)

# %%
data
# Out:
#       No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1         2012.917      32.0                     84.87882  24.98298
# 1      2         2012.917      19.5                    306.59470  24.98034
# 2      3         2013.583      13.3                    561.98450  24.98746
# 3      4         2013.500      13.3                    561.98450  24.98746
# 4      5         2012.833       5.0                    390.56840  24.97937
# ..   ...              ...       ...                          ...       ...
# 413  410         2013.000      13.7                   4082.01500  24.94155
# 414  411         2012.667       5.6                     90.45606  24.97433
# 415  412         2013.250      18.8                    390.96960  24.97923
# 416  413         2013.000       8.1                    104.81010  24.96674
# 417  414         2013.500       6.5                     90.45606  24.97433
#
#      longitude  housePriceOfUnitArea  standardized_houseAge
# ...

# %%
#Used .loc[] to display all rows from 0-10
data.loc[0:10, :]
# Out:
#     No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0    1         2012.917      32.0                     84.87882  24.98298
# 1    2         2012.917      19.5                    306.59470  24.98034
# 2    3         2013.583      13.3                    561.98450  24.98746
# 3    4         2013.500      13.3                    561.98450  24.98746
# 4    5         2012.833       5.0                    390.56840  24.97937
# 5    6         2012.667       7.1                   2175.03000  24.96305
# 6    7         2012.667      34.5                    623.47310  24.97933
# 7    8         2013.417      20.3                    287.60250  24.98042
# 8    9         2013.500      31.7                   5512.03800  24.95095
# 9   10         2013.417      17.9                   1783.18000  24.96731
# 10  11         2013.083      34.8                    405.21340  24.97349
#
#     longitude  housePriceOfUnitArea  standardized_houseAge
# ...

# %%
#Used .iloc[] to display the first 10 rows.
data.iloc[0:11, :]
# Out:
#     No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0    1         2012.917      32.0                     84.87882  24.98298
# 1    2         2012.917      19.5                    306.59470  24.98034
# 2    3         2013.583      13.3                    561.98450  24.98746
# 3    4         2013.500      13.3                    561.98450  24.98746
# 4    5         2012.833       5.0                    390.56840  24.97937
# 5    6         2012.667       7.1                   2175.03000  24.96305
# 6    7         2012.667      34.5                    623.47310  24.97933
# 7    8         2013.417      20.3                    287.60250  24.98042
# 8    9         2013.500      31.7                   5512.03800  24.95095
# 9   10         2013.417      17.9                   1783.18000  24.96731
# 10  11         2013.083      34.8                    405.21340  24.97349
#
#     longitude  housePriceOfUnitArea  standardized_houseAge
# ...

# %%
data.drop_duplicates()
# Out:
#       No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1         2012.917      32.0                     84.87882  24.98298
# 1      2         2012.917      19.5                    306.59470  24.98034
# 2      3         2013.583      13.3                    561.98450  24.98746
# 3      4         2013.500      13.3                    561.98450  24.98746
# 4      5         2012.833       5.0                    390.56840  24.97937
# ..   ...              ...       ...                          ...       ...
# 413  410         2013.000      13.7                   4082.01500  24.94155
# 414  411         2012.667       5.6                     90.45606  24.97433
# 415  412         2013.250      18.8                    390.96960  24.97923
# 416  413         2013.000       8.1                    104.81010  24.96674
# 417  414         2013.500       6.5                     90.45606  24.97433
#
#      longitude  housePriceOfUnitArea  standardized_houseAge
# ...

# %%
#Used .iloc[] to display the first 10 rows.
data.drop_duplicates(subset=['longitude'])
# Out:
#       No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1         2012.917      32.0                     84.87882  24.98298
# 1      2         2012.917      19.5                    306.59470  24.98034
# 2      3         2013.583      13.3                    561.98450  24.98746
# 4      5         2012.833       5.0                    390.56840  24.97937
# 5      6         2012.667       7.1                   2175.03000  24.96305
# ..   ...              ...       ...                          ...       ...
# 396  393         2013.083      42.7                    443.80200  24.97927
# 398  395         2013.500      32.6                   4136.27100  24.95544
# 400  397         2012.667      37.1                    918.63570  24.97198
# 407  404         2012.667      30.9                    161.94200  24.98353
# 412  409         2013.417      18.5                   2175.74400  24.96330
#
#      longitude  housePriceOfUnitArea  standardized_houseAge
# ...

# %%
#Found and removed any duplicate data rows.
data.drop_duplicates(subset=['latitude'])
# Out:
#       No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1         2012.917      32.0                     84.87882  24.98298
# 1      2         2012.917      19.5                    306.59470  24.98034
# 2      3         2013.583      13.3                    561.98450  24.98746
# 4      5         2012.833       5.0                    390.56840  24.97937
# 5      6         2012.667       7.1                   2175.03000  24.96305
# ..   ...              ...       ...                          ...       ...
# 407  404         2012.667      30.9                    161.94200  24.98353
# 409  406         2012.667      23.0                    130.99450  24.95663
# 410  407         2013.167       1.9                    372.13860  24.97293
# 412  409         2013.417      18.5                   2175.74400  24.96330
# 415  412         2013.250      18.8                    390.96960  24.97923
#
#      longitude  housePriceOfUnitArea  standardized_houseAge
# ...

# %%
data.drop_duplicates(subset=['distanceToNearestMRTstation'])
# Out:
#       No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1         2012.917      32.0                     84.87882  24.98298
# 1      2         2012.917      19.5                    306.59470  24.98034
# 2      3         2013.583      13.3                    561.98450  24.98746
# 4      5         2012.833       5.0                    390.56840  24.97937
# 5      6         2012.667       7.1                   2175.03000  24.96305
# ..   ...              ...       ...                          ...       ...
# 407  404         2012.667      30.9                    161.94200  24.98353
# 409  406         2012.667      23.0                    130.99450  24.95663
# 410  407         2013.167       1.9                    372.13860  24.97293
# 412  409         2013.417      18.5                   2175.74400  24.96330
# 415  412         2013.250      18.8                    390.96960  24.97923
#
#      longitude  housePriceOfUnitArea  standardized_houseAge
# ...

# %%
data.drop_duplicates(subset=['longitude', 'latitude', 'distanceToNearestMRTstation'], inplace=True)

# %%
data.housePriceOfUnitArea.mean()
# Out:
# 36.898046875

# %%
data.head()
# Out:
#    No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0   1         2012.917      32.0                     84.87882  24.98298
# 1   2         2012.917      19.5                    306.59470  24.98034
# 2   3         2013.583      13.3                    561.98450  24.98746
# 4   5         2012.833       5.0                    390.56840  24.97937
# 5   6         2012.667       7.1                   2175.03000  24.96305
#
#    longitude  housePriceOfUnitArea  standardized_houseAge
# 0  121.54024                   NaN               1.258245
# 1  121.53951                  42.2               0.164474
# 2  121.54391                  47.3              -0.378037
# 4  121.54245                  43.1              -1.104301
# 5  121.51254                  32.1              -0.920547

# %%
data.fillna(0)
# Out:
#       No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1         2012.917      32.0                     84.87882  24.98298
# 1      2         2012.917      19.5                    306.59470  24.98034
# 2      3         2013.583      13.3                    561.98450  24.98746
# 4      5         2012.833       5.0                    390.56840  24.97937
# 5      6         2012.667       7.1                   2175.03000  24.96305
# ..   ...              ...       ...                          ...       ...
# 407  404         2012.667      30.9                    161.94200  24.98353
# 409  406         2012.667      23.0                    130.99450  24.95663
# 410  407         2013.167       1.9                    372.13860  24.97293
# 412  409         2013.417      18.5                   2175.74400  24.96330
# 415  412         2013.250      18.8                    390.96960  24.97923
#
#      longitude  housePriceOfUnitArea  standardized_houseAge
# ...

# %%
#Found any missing values and fill them with the mean
data.fillna(36.898046875)
# Out:
#       No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1         2012.917      32.0                     84.87882  24.98298
# 1      2         2012.917      19.5                    306.59470  24.98034
# 2      3         2013.583      13.3                    561.98450  24.98746
# 4      5         2012.833       5.0                    390.56840  24.97937
# 5      6         2012.667       7.1                   2175.03000  24.96305
# ..   ...              ...       ...                          ...       ...
# 407  404         2012.667      30.9                    161.94200  24.98353
# 409  406         2012.667      23.0                    130.99450  24.95663
# 410  407         2013.167       1.9                    372.13860  24.97293
# 412  409         2013.417      18.5                   2175.74400  24.96330
# 415  412         2013.250      18.8                    390.96960  24.97923
#
#      longitude  housePriceOfUnitArea  standardized_houseAge
# ...

# %%
data.fillna(36.898046875, inplace=True)

# %%
data
# Out:
#       No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1         2012.917      32.0                     84.87882  24.98298
# 1      2         2012.917      19.5                    306.59470  24.98034
# 2      3         2013.583      13.3                    561.98450  24.98746
# 4      5         2012.833       5.0                    390.56840  24.97937
# 5      6         2012.667       7.1                   2175.03000  24.96305
# ..   ...              ...       ...                          ...       ...
# 407  404         2012.667      30.9                    161.94200  24.98353
# 409  406         2012.667      23.0                    130.99450  24.95663
# 410  407         2013.167       1.9                    372.13860  24.97293
# 412  409         2013.417      18.5                   2175.74400  24.96330
# 415  412         2013.250      18.8                    390.96960  24.97923
#
#      longitude  housePriceOfUnitArea  standardized_houseAge
# ...
