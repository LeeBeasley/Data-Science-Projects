# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

df= pd.read_csv("loanP_train.csv") #Reading the dataset in a dataframe Pandas

# %%
df.head() # look at few top rows by using the function head()
# Out:
#   Loan_ID Gender Marital_Status Dependents Graduate Self_Employed  \
# 0  LI0100   Male         Single          0      Yes            No
# 1  LI0101   Male        Married          1      Yes            No
# 2  LI0102   Male        Married          0      Yes           Yes
# 3  LI0103   Male        Married          0       No            No
# 4  LI0104   Male         Single          0      Yes            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.describe() #look at summary
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       599.000000         599.000000  578.000000        585.000000
# mean       5420.687813        1563.913055  145.434256        342.461538
# std        6169.168633        2456.618360   84.596463         64.868352
# min         150.000000           0.000000    9.000000         12.000000
# 25%        2874.000000           0.000000  100.000000        360.000000
# 50%        3812.000000        1210.000000  126.500000        360.000000
# 75%        5807.500000        2279.000000  165.000000        360.000000
# max       81000.000000       33837.000000  700.000000        480.000000
#
#        Credit_History
# count       550.00000
# mean          0.84000
# std           0.36694
# min           0.00000
# 25%           1.00000
# 50%           1.00000
# 75%           1.00000
# max           1.00000

# %%
df['LoanAmount'].hist(bins=50) #there are some extreme values, but most of data 100 and 300
# Out:
# <Axes: >

# %%
df['ApplicantIncome'].hist(bins=50) #there are some extreme values, but most of data is between 0 and 10000
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

#DataFrame to mimic your data structure
data = {
    'Credit_History': [0, 1],  # Example credit history categories
    'Count of Applicants': [100, 200]  # Corresponding counts of applicants
}

# Create a DataFrame
df = pd.DataFrame(data)

# %%
templ = pd.DataFrame(data)

# %%
# Create a figure and a set of subplots
fig = plt.figure(figsize=(8,4))
ax1 = fig.add_subplot(121)
ax1.set_xlabel('Credit History')
ax1.set_ylabel('Count of Applicants')
ax1.set_title("Applicants by Credit History")

# Plotting the data
templ.plot(kind='bar', ax=ax1, x='Credit_History', y='Count of Applicants')
# Out:
# <Axes: title={'center': 'Applicants by Credit History'}, xlabel='Credit_History', ylabel='Count of Applicants'>

# %%
df = pd.read_csv('loanP_train.csv')
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 599 entries, 0 to 598
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            599 non-null    object
#  1   Gender             586 non-null    object
#  2   Marital_Status     596 non-null    object
#  3   Dependents         584 non-null    object
#  4   Graduate           599 non-null    object
#  5   Self_Employed      569 non-null    object
#  6   ApplicantIncome    599 non-null    int64
#  7   CoapplicantIncome  599 non-null    float64
#  8   LoanAmount         578 non-null    float64
#  9   Loan_Amount_Term   585 non-null    float64
#  10  Credit_History     550 non-null    float64
#  11  Property_Area      599 non-null    object
#  12  Loan_Status        599 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 61.0+ KB
# None

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# Loan_ID               0
# Gender               13
# Marital_Status        3
# Dependents           15
# Graduate              0
# Self_Employed        30
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           21
# Loan_Amount_Term     14
# Credit_History       49
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df['LoanAmount'].fillna(df['LoanAmount'].mean(), inplace=True)
df['Credit_History'].fillna(df['Credit_History'].mean(), inplace=True)#filling missing values

# %%
df.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# Loan_ID               0
# Gender               13
# Marital_Status        3
# Dependents           15
# Graduate              0
# Self_Employed        30
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Marital_Status        object
# Dependents            object
# Graduate              object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
one = pd.DataFrame(np.random.randn(5,4))
one
# Out:
#           0         1         2         3
# 0 -1.103974 -0.256760  0.261004  0.422720
# 1  0.817280  0.731710 -0.837379 -0.762207
# 2 -0.231772  0.195196  2.005138  0.659366
# 3  1.681387 -0.975233  0.291797 -0.063509
# 4 -0.636129  1.327136  1.027590 -0.629131

# %%
two = pd.DataFrame(np.random.randn(5,4))
two
# Out:
#           0         1         2         3
# 0 -2.087799 -0.636813  1.160547  0.752270
# 1 -1.128373  0.412719  0.229969 -0.244379
# 2  0.344370  1.821368 -0.562249 -0.364382
# 3  0.182710 -0.246527 -1.160912 -0.866264
# 4  0.723789 -0.178250 -0.522180 -0.665626

# %%
pd.concat([one, two])
# Out:
#           0         1         2         3
# 0 -1.103974 -0.256760  0.261004  0.422720
# 1  0.817280  0.731710 -0.837379 -0.762207
# 2 -0.231772  0.195196  2.005138  0.659366
# 3  1.681387 -0.975233  0.291797 -0.063509
# 4 -0.636129  1.327136  1.027590 -0.629131
# 0 -2.087799 -0.636813  1.160547  0.752270
# 1 -1.128373  0.412719  0.229969 -0.244379
# 2  0.344370  1.821368 -0.562249 -0.364382
# 3  0.182710 -0.246527 -1.160912 -0.866264
# 4  0.723789 -0.178250 -0.522180 -0.665626

# %%
left = pd.DataFrame({'key': ['foo', 'bar'], 'lval': [1, 2]})
left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right = pd.DataFrame({'key':['foo', 'bar', 'bar'], 'rval': [3, 4, 5]})
right
# Out:
#    key  rval
# 0  foo     3
# 1  bar     4
# 2  bar     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     3
# 1  bar     2     4
# 2  bar     2     5

# %%
#Import models from scikit learn module:
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn import metrics

# %%
pip install -U scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Extracting only the independent variables
X =  df.iloc[:, [8,10]].values #credit history and loan amount

# Extracting only the dependent variables
y = df.iloc[:, 12].values

# %%
#Splitting the dataset int the Training set and Test set

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
# Fitting logistics regression to training dataset
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
                  intercept_scaling=1, max_iter=100, multi_class='ovr',n_jobs=1,
                  penalty='12', random_state=0, solver='liblinear', tol=0.0001,
                  verbose=0, warm_start=False)
# Out:
# LogisticRegression(multi_class='ovr', n_jobs=1, penalty='12', random_state=0,
#                    solver='liblinear')

# %%
#Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred
# Out:
# array(['Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N',
#        'Y', 'Y', 'N', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'N', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y'], dtype=object)

# %%
#building the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[ 18,  27],
#        [  2, 103]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.8066666666666666
